# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from  sklearn.ensemble import RandomForestClassifier
df_train = pd.read_csv('fraudTrain.csv', header = 0)
df_test = pd.read_csv('fraudTest.csv', header = 0)
df_train.head()
df_test.head()
df_train.tail()
df_train.shape
df_test.shape
df_train.size
df_test.size
df_train.info()
df_test.info()
df_train.describe()
df_test.describe()
df_train.isnull().values.any()
df_test.isnull().values.any()
df_train.count()
df_test.count()
df_combined = pd.concat([df_train, df_test], axis = 0)
df_combined.head()
df_combined.shape
df_combined.size
df_combined.info()
df_combined.drop(labels = ["first", "last", "job", "dob", "trans_num", "street", "trans_date_trans_time","city","state"], axis = 1, inplace = True)
df_combined.head()
sns.countplot(x='gender', data=df_combined)
plt.title("Gender Distribution")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217322 entries, 0 to 217321
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             217322 non-null  int64
#  1   trans_date_trans_time  217322 non-null  object
#  2   cc_num                 217322 non-null  int64
#  3   merchant               217322 non-null  object
#  4   category               217322 non-null  object
#  5   amt                    217322 non-null  float64
#  6   first                  217322 non-null  object
#  7   last                   217322 non-null  object
#  8   gender                 217322 non-null  object
#  9   street                 217322 non-null  object
#  10  city                   217322 non-null  object
#  11  state                  217322 non-null  object
#  12  zip                    217322 non-null  int64
#  13  lat                    217322 non-null  float64
#  14  long                   217322 non-null  float64
#  15  city_pop               217321 non-null  float64
#  16  job                    217321 non-null  object
#  17  dob                    217321 non-null  object
#  18  trans_num              217321 non-null  object
#  19  unix_time              217321 non-null  float64
#  20  merch_lat              217321 non-null  float64
#  21  merch_long             217321 non-null  float64
#  22  is_fraud               217321 non-null  float64
# dtypes: float64(8), int64(3), object(12)
# memory usage: 38.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213403 entries, 0 to 213402
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             213403 non-null  int64
#  1   trans_date_trans_time  213403 non-null  object
#  2   cc_num                 213403 non-null  int64
#  3   merchant               213403 non-null  object
#  4   category               213403 non-null  object
#  5   amt                    213403 non-null  float64
#  6   first                  213403 non-null  object
#  7   last                   213403 non-null  object
#  8   gender                 213403 non-null  object
#  9   street                 213403 non-null  object
#  10  city                   213403 non-null  object
#  11  state                  213403 non-null  object
#  12  zip                    213403 non-null  int64
#  13  lat                    213403 non-null  float64
#  14  long                   213403 non-null  float64
#  15  city_pop               213402 non-null  float64
#  16  job                    213402 non-null  object
#  17  dob                    213402 non-null  object
#  18  trans_num              213402 non-null  object
#  19  unix_time              213402 non-null  float64
#  20  merch_lat              213402 non-null  float64
#  21  merch_long             213402 non-null  float64
#  22  is_fraud               213402 non-null  float64
# dtypes: float64(8), int64(3), object(12)
# memory usage: 37.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 430725 entries, 0 to 213402
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             430725 non-null  int64
#  1   trans_date_trans_time  430725 non-null  object
#  2   cc_num                 430725 non-null  int64
#  3   merchant               430725 non-null  object
#  4   category               430725 non-null  object
#  5   amt                    430725 non-null  float64
#  6   first                  430725 non-null  object
#  7   last                   430725 non-null  object
#  8   gender                 430725 non-null  object
#  9   street                 430725 non-null  object
#  10  city                   430725 non-null  object
#  11  state                  430725 non-null  object
#  12  zip                    430725 non-null  int64
#  13  lat                    430725 non-null  float64
#  14  long                   430725 non-null  float64
#  15  city_pop               430723 non-null  float64
#  16  job                    430723 non-null  object
#  17  dob                    430723 non-null  object
#  18  trans_num              430723 non-null  object
#  19  unix_time              430723 non-null  float64
#  20  merch_lat              430723 non-null  float64
#  21  merch_long             430723 non-null  float64
#  22  is_fraud               430723 non-null  float64
# dtypes: float64(8), int64(3), object(12)
# memory usage: 78.9+ MB
